# %%
import pandas as pd

# %% [markdown]
# # TheMovieDB.org - tmdb.movies.csv
#
# *only movies from 2010-2018
# *from https://developers.themoviedb.org/3/discover/movie-discover

# %%
tmdb_df = pd.read_csv("data/tmdb.movies.csv.gz")
tmdb_df.head()
# Out:
#    Unnamed: 0            genre_ids     id original_language  \
# 0           0      [12, 14, 10751]  12444                en
# 1           1  [14, 12, 16, 10751]  10191                en
# 2           2        [12, 28, 878]  10138                en
# 3           3      [16, 35, 10751]    862                en
# 4           4        [28, 878, 12]  27205                en
#
#                                  original_title  popularity release_date  \
# 0  Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# 1                      How to Train Your Dragon      28.734   2010-03-26
# 2                                    Iron Man 2      28.515   2010-05-07
# 3                                     Toy Story      28.005   1995-11-22
# 4                                     Inception      27.920   2010-07-16
#
#                                           title  vote_average  vote_count
# 0  Harry Potter and the Deathly Hallows: Part 1           7.7       10788
# 1                      How to Train Your Dragon           7.7        7610
# 2                                    Iron Man 2           6.8       12368
# 3                                     Toy Story           7.9       10174
# 4                                     Inception           8.3       22186

# %%
tmdb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26517 entries, 0 to 26516
# Data columns (total 10 columns):
# Unnamed: 0           26517 non-null int64
# genre_ids            26517 non-null object
# id                   26517 non-null int64
# original_language    26517 non-null object
# original_title       26517 non-null object
# popularity           26517 non-null float64
# release_date         26517 non-null object
# title                26517 non-null object
# vote_average         26517 non-null float64
# vote_count           26517 non-null int64
# dtypes: float64(2), int64(3), object(5)
# memory usage: 2.0+ MB

# %% [markdown]
# # TheMovieDB.org - tn.movie_budgets.csv
#
# *includes all movies from https://www.the-numbers.com/movie/budgets/all

# %%
tn_budgets_df = pd.read_csv("data/tn.movie_budgets.csv.gz")
tn_budgets_df.head()
# Out:
#    id  release_date                                        movie  \
# 0   1  Dec 18, 2009                                       Avatar
# 1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   3   Jun 7, 2019                                 Dark Phoenix
# 3   4   May 1, 2015                      Avengers: Age of Ultron
# 4   5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#   production_budget domestic_gross worldwide_gross
# 0      $425,000,000   $760,507,625  $2,776,345,279
# 1      $410,600,000   $241,063,875  $1,045,663,875
# 2      $350,000,000    $42,762,350    $149,762,350
# 3      $330,600,000   $459,005,868  $1,403,013,963
# 4      $317,000,000   $620,181,382  $1,316,721,747

# %%
tn_budgets_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5782 entries, 0 to 5781
# Data columns (total 6 columns):
# id                   5782 non-null int64
# release_date         5782 non-null object
# movie                5782 non-null object
# production_budget    5782 non-null object
# domestic_gross       5782 non-null object
# worldwide_gross      5782 non-null object
# dtypes: int64(1), object(5)
# memory usage: 271.1+ KB

# %% [markdown]
# # Rotten Tomatoes - Reviews
#
# *from https://www.kaggle.com/rpnuser8182/rotten-tomatoes

# %%
rt_reviews_df = pd.read_csv("data/rt.reviews.tsv.gz", delimiter='\t', encoding='latin-1')
rt_reviews_df.head()

rt_reviews_df.loc[rt_reviews_df['top_critic'] == 1]
# Out:
#          id                                             review rating   fresh  \
# 24        3  The rapid dialogue is dry and mannered, like a...  2.5/4  rotten
# 47        3  It feels like each and every moment bursts for...    2/4  rotten
# 50        3  There's not really a movie there, nothing that...    2/4  rotten
# 54        3  The film is all too faithful to its un-cinemat...  1.5/4  rotten
# 55        3  Cosmopolis," because of its allegiance to the ...    2/4  rotten
# 58        3  Poor Pattinson does the best he can. He's not ...    2/4  rotten
# 60        3  The story seems to cleave into cerebral disqui...    NaN   fresh
# 62        3  The movie isn't for everyone. But if it grabs ...    3/4   fresh
# 64        3  A flawlessly directed film about enigmatic peo...    2/4  rotten
# 77        3  Despite the constrictions, Cronenberg keeps th...    NaN   fresh
# 78        3  It is one of the director's better movies of r...    NaN   fresh
# 81        3  David Cronenberg meets Don DeLillo at last, an...    1/4  rotten
# 83        3  I took a strange pleasure in submitting to thi...    NaN   fresh
# 86        3  I never imagined describing a film as a cross ...    NaN   fresh
# 87        3  It's all vapid snark, didactic sermonizing and...    2/4  rotten
# 88        3  DeLillo's brilliant analysis of the destructiv...  2.5/5  rotten
# 89        3  It's like a dream that engages and drifts, unt...    NaN   fresh
# 90        3  Frustratingly bland work from lead Robert Patt...    2/5  rotten
# 91        3          Conventional it is not. Engrossing it is.    NaN   fresh
# 92        3  Mr. Cronenberg's direction throughout "Cosmopo...  3.5/5   fresh
# 93        3  If you can get past the psychological density ...    3/4   fresh
# 95        3  Sometimes, even a little gratuitous nudity can...    1/4  rotten
# 96        3  Cronenberg turns a difficult, sometimes frustr...      C  rotten
# 98        3  Cosmopolis" is Cronenberg's best film since "e...     A-   fresh
# 99        3  We're supposed to be feeling . . . something. ...    NaN  rotten
# 100       3  Cosmopolis is almost certainly some kind of ma...    5/5   fresh
# 104       3  The more abstract and overtly stylized Cosmopo...     B-   fresh
# 108       3  A sensual, propulsive thriller, the apocalypse...    4/5   fresh
# 128       3  Cosmopolis demonstrates that even a flawed thr...      B   fresh
# 152       3                 [A] vapid, claustrophobic drama...    NaN  rotten
# ...     ...                                                ...    ...     ...
# 54331  1997  This is a dismal, dreary and fairly desperate ...  1.5/4  rotten
# 54332  1997  A respectably funny -- but small -- effort, a ...    NaN   fresh
# 54333  1997  Curtin and Aykroyd rely on old standbys... Whe...    NaN  rotten
# 54337  1997                                                NaN     B-   fresh
# 54345  1997                                                NaN     B-   fresh
# 54352  1999  In The Sandlot's nostalgia for simpler times, ...    2/4  rotten
# 54353  1999  The kids even have their own treehouse, which ...    NaN  rotten
# 54354  1999  A solid double rather than a grand slam, The S...    3/4   fresh
# 54360  1999  There's a snappy change-of-pace gag involving ...    NaN  rotten
# 54366  1999  Sweet and sincere, the film is also a remarkab...    NaN  rotten
# 54368  1999  Ever since Stand by Me, it seems that every Bo...    NaN  rotten
# 54369  1999  Nothing about his modest coming-of-age comedy ...    NaN  rotten
# 54374  1999  Predictable as the movie is, the Field of Drea...    NaN   fresh
# 54375  1999  This is a movie... that allows its kids to be ...    3/4   fresh
# 54376  1999  The Sandlot isn't well made but it's alive wit...    NaN   fresh
# 54377  1999  Older kids and overgrown ones too probably wil...    NaN  rotten
# 54381  1999  Old baseball wisdom: The best teams win with s...     B+   fresh
# 54398  2000  The movie fails to live up to the sum of its p...    NaN  rotten
# 54402  2000  The film is a contrivance, as artificial as th...      B   fresh
# 54403  2000  Reno does what he can in a thankless situation...  1.5/4  rotten
# 54404  2000  Like being trapped inside a huge video game, w...    2/4  rotten
# 54407  2000  One scarcely needs the subtitles to enjoy this...    NaN   fresh
# 54410  2000  A silly, cross-cultural shoot-'em-up -- the so...    2/4   fresh
# 54411  2000  Don't let the subtitles fool you; the movie on...    2/4  rotten
# 54417  2000  The funny thing is, I didn't mind all this con...    NaN   fresh
# 54419  2000            Sleek, shallow, but frequently amusing.  2.5/4   fresh
# 54420  2000  The spaniel-eyed Jean Reno infuses Hubert with...    3/4   fresh
# 54424  2000  Dawdles and drags when it should pop; it doesn...  1.5/5  rotten
# 54426  2000  The film lapses too often into sugary sentimen...    NaN  rotten
# 54427  2000  The real charm of this trifle is the deadpan c...    NaN   fresh
#
#                    critic  top_critic                  publisher  \
# 24           Joe Williams           1    St. Louis Post-Dispatch
# 47        Stephanie Merry           1            Washington Post
# 50           Mick LaSalle           1    San Francisco Chronicle
# 54           Colin Covert           1   Minneapolis Star Tribune
# 55        Moira MacDonald           1              Seattle Times
# 58            Mark Feeney           1               Boston Globe
# 60            J. R. Jones           1             Chicago Reader
# 62         Rene Rodriguez           1               Miami Herald
# 64            Roger Ebert           1          Chicago Sun-Times
# 77            David Denby           1                 New Yorker
# 78            Bilge Ebiri           1  New York Magazine/Vulture
# 81             Kyle Smith           1              New York Post
# 83           Dana Stevens           1                      Slate
# 86         Alonso Duralde           1                    TheWrap
# 87           Claudia Puig           1                  USA Today
# 88          Betsy Sharkey           1          Los Angeles Times
# 89           Scott Tobias           1                        NPR
# 90     Elizabeth Weitzman           1        New York Daily News
# 91          John Anderson           1        Wall Street Journal
reviews_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54432 entries, 0 to 54431
# Data columns (total 8 columns):
# id            54432 non-null int64
# review        48869 non-null object
# rating        40915 non-null object
# fresh         54432 non-null object
# critic        51710 non-null object
# top_critic    54432 non-null int64
# publisher     54123 non-null object
# date          54432 non-null object
# dtypes: int64(2), object(6)
# memory usage: 3.3+ MB

# %% [markdown]
# # Rotten Tomatoes - Movie Info

# %%
rt_movie_df = pd.read_csv("data/rt.movie_info.tsv.gz", delimiter='\t')
rt_movie_df.head()
# Out:
#    id                                           synopsis rating  \
# 0   1  This gritty, fast-paced, and innovative police...      R
# 1   3  New York City, not-too-distant-future: Eric Pa...      R
# 2   5  Illeana Douglas delivers a superb performance ...      R
# 3   6  Michael Douglas runs afoul of a treacherous su...      R
# 4   7                                                NaN     NR
#
#                                  genre          director  \
# 0  Action and Adventure|Classics|Drama  William Friedkin
# 1    Drama|Science Fiction and Fantasy  David Cronenberg
# 2    Drama|Musical and Performing Arts    Allison Anders
# 3           Drama|Mystery and Suspense    Barry Levinson
# 4                        Drama|Romance    Rodney Bennett
#
#                             writer  theater_date      dvd_date currency  \
# 0                   Ernest Tidyman   Oct 9, 1971  Sep 25, 2001      NaN
# 1     David Cronenberg|Don DeLillo  Aug 17, 2012   Jan 1, 2013        $
# 2                   Allison Anders  Sep 13, 1996  Apr 18, 2000      NaN
# 3  Paul Attanasio|Michael Crichton   Dec 9, 1994  Aug 27, 1997      NaN
# 4                     Giles Cooper           NaN           NaN      NaN
#
#   box_office      runtime             studio
# 0        NaN  104 minutes                NaN
# 1    600,000  108 minutes  Entertainment One
# 2        NaN  116 minutes                NaN
# 3        NaN  128 minutes                NaN
# 4        NaN  200 minutes                NaN

# %%
rt_movie_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1560 entries, 0 to 1559
# Data columns (total 12 columns):
# id              1560 non-null int64
# synopsis        1498 non-null object
# rating          1557 non-null object
# genre           1552 non-null object
# director        1361 non-null object
# writer          1111 non-null object
# theater_date    1201 non-null object
# dvd_date        1201 non-null object
# currency        340 non-null object
# box_office      340 non-null object
# runtime         1530 non-null object
# studio          494 non-null object
# dtypes: int64(1), object(11)
# memory usage: 146.3+ KB

# %% [markdown]
# # IMDB Title Ratings
#
# *all IMDB from 2010-2018
# *from https://www.imdb.com/interfaces/

# %%
imdb_title_ratings_df = pd.read_csv("data/imdb.title.ratings.csv.gz")
imdb_title_ratings_df.head()
# Out:
#        tconst  averagerating  numvotes
# 0  tt10356526            8.3        31
# 1  tt10384606            8.9       559
# 2   tt1042974            6.4        20
# 3   tt1043726            4.2     50352
# 4   tt1060240            6.5        21

# %%
imdb_title_ratings_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73856 entries, 0 to 73855
# Data columns (total 1 columns):
# tconst,"averagerating","numvotes"    73856 non-null object
# dtypes: object(1)
# memory usage: 577.1+ KB

# %% [markdown]
# # IMDB Title Principals

# %%
imdb_title_principals_df = pd.read_csv("data/imdb.title.principals.csv.gz")
imdb_title_principals_df.head()
# Out:
#       tconst  ordering     nconst  category       job        characters
# 0  tt0111414         1  nm0246005     actor       NaN       ["The Man"]
# 1  tt0111414         2  nm0398271  director       NaN               NaN
# 2  tt0111414         3  nm3739909  producer  producer               NaN
# 3  tt0323808        10  nm0059247    editor       NaN               NaN
# 4  tt0323808         1  nm3579312   actress       NaN  ["Beth Boothby"]

# %%
imdb_title_principals_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1028186 entries, 0 to 1028185
# Data columns (total 6 columns):
# tconst        1028186 non-null object
# ordering      1028186 non-null int64
# nconst        1028186 non-null object
# category      1028186 non-null object
# job           177684 non-null object
# characters    393360 non-null object
# dtypes: int64(1), object(5)
# memory usage: 47.1+ MB
